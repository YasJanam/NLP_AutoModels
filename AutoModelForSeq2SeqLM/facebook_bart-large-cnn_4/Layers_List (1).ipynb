# %%
from transformers import AutoModelForSeq2SeqLM

# %%
model_name = "facebook/bart-large-cnn"
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# %% [markdown]
# #### 🟡 **Layers-List**

# %%
for name, module in model.named_modules():
  print(f"{name: <50}{module.__class__.__name__}")
  print("---------------------------------------------------------------------")
# Out:
#                                                   BartForConditionalGeneration
# ---------------------------------------------------------------------
# model                                             BartModel
# ---------------------------------------------------------------------
# model.shared                                      BartScaledWordEmbedding
# ---------------------------------------------------------------------
# model.encoder                                     BartEncoder
# ---------------------------------------------------------------------
# model.encoder.embed_tokens                        BartScaledWordEmbedding
# ---------------------------------------------------------------------
# model.encoder.embed_positions                     BartLearnedPositionalEmbedding
# ---------------------------------------------------------------------
# model.encoder.layers                              ModuleList
# ---------------------------------------------------------------------
# model.encoder.layers.0                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.0.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.0.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.0.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.0.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.0.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.0.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.0.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.0.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.0.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.0.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.1                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.1.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.1.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.1.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.1.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.1.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.1.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.1.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.1.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.1.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.1.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.2                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.2.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.2.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.2.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.2.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.2.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.2.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.2.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.2.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.2.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.2.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.3                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.3.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.3.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.3.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.3.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.3.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.3.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.3.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.3.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.3.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.3.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.4                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.4.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.4.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.4.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.4.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.4.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.4.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.4.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.4.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.4.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.4.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.5                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.5.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.5.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.5.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.5.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.5.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.5.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.5.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.5.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.5.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.5.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.6                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.6.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.6.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.6.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.6.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.6.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.6.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.6.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.6.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.6.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.6.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.7                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.7.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.7.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.7.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.7.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.7.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.7.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.7.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.7.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.7.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.7.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.8                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.8.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.8.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.8.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.8.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.8.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.8.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.8.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.8.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.8.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.8.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.9                            BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.9.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.9.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.9.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.9.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.encoder.layers.9.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.encoder.layers.9.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.9.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.9.fc1                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.9.fc2                        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.9.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.10                           BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.10.self_attn                 BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.10.self_attn.k_proj          Linear
# ---------------------------------------------------------------------
# model.encoder.layers.10.self_attn.v_proj          Linear
# ---------------------------------------------------------------------
# model.encoder.layers.10.self_attn.q_proj          Linear
# ---------------------------------------------------------------------
# model.encoder.layers.10.self_attn.out_proj        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.10.self_attn_layer_norm      LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.10.activation_fn             GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.10.fc1                       Linear
# ---------------------------------------------------------------------
# model.encoder.layers.10.fc2                       Linear
# ---------------------------------------------------------------------
# model.encoder.layers.10.final_layer_norm          LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.11                           BartEncoderLayer
# ---------------------------------------------------------------------
# model.encoder.layers.11.self_attn                 BartAttention
# ---------------------------------------------------------------------
# model.encoder.layers.11.self_attn.k_proj          Linear
# ---------------------------------------------------------------------
# model.encoder.layers.11.self_attn.v_proj          Linear
# ---------------------------------------------------------------------
# model.encoder.layers.11.self_attn.q_proj          Linear
# ---------------------------------------------------------------------
# model.encoder.layers.11.self_attn.out_proj        Linear
# ---------------------------------------------------------------------
# model.encoder.layers.11.self_attn_layer_norm      LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layers.11.activation_fn             GELUActivation
# ---------------------------------------------------------------------
# model.encoder.layers.11.fc1                       Linear
# ---------------------------------------------------------------------
# model.encoder.layers.11.fc2                       Linear
# ---------------------------------------------------------------------
# model.encoder.layers.11.final_layer_norm          LayerNorm
# ---------------------------------------------------------------------
# model.encoder.layernorm_embedding                 LayerNorm
# ---------------------------------------------------------------------
# model.decoder                                     BartDecoder
# ---------------------------------------------------------------------
# model.decoder.embed_tokens                        BartScaledWordEmbedding
# ---------------------------------------------------------------------
# model.decoder.embed_positions                     BartLearnedPositionalEmbedding
# ---------------------------------------------------------------------
# model.decoder.layers                              ModuleList
# ---------------------------------------------------------------------
# model.decoder.layers.0                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.0.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.0.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.0.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.0.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.0.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.0.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.0.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.1                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.1.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.1.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.1.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.1.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.1.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.1.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.1.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.2                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.2.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.2.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.2.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.2.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.2.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.2.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.2.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.3                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.3.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.3.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.3.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.3.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.3.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.3.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.3.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.4                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.4.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.4.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.4.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.4.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.4.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.4.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.4.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.5                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.5.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.5.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.5.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.5.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.5.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.5.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.5.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.6                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.6.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.6.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.6.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.6.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.6.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.6.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.6.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.7                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.7.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.7.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.7.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.7.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.7.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.7.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.7.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.8                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.8.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.8.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.8.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.8.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.8.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.8.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.8.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.9                            BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.9.self_attn                  BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.9.self_attn.k_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.self_attn.v_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.self_attn.q_proj           Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.self_attn.out_proj         Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.activation_fn              GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.9.self_attn_layer_norm       LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.9.encoder_attn               BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.9.encoder_attn.k_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.encoder_attn.v_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.encoder_attn.q_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.encoder_attn.out_proj      Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.encoder_attn_layer_norm    LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.9.fc1                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.fc2                        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.9.final_layer_norm           LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.10                           BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.10.self_attn                 BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.10.self_attn.k_proj          Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.self_attn.v_proj          Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.self_attn.q_proj          Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.self_attn.out_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.activation_fn             GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.10.self_attn_layer_norm      LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.10.encoder_attn              BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.10.encoder_attn.k_proj       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.encoder_attn.v_proj       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.encoder_attn.q_proj       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.encoder_attn.out_proj     Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.encoder_attn_layer_norm   LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.10.fc1                       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.fc2                       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.10.final_layer_norm          LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.11                           BartDecoderLayer
# ---------------------------------------------------------------------
# model.decoder.layers.11.self_attn                 BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.11.self_attn.k_proj          Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.self_attn.v_proj          Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.self_attn.q_proj          Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.self_attn.out_proj        Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.activation_fn             GELUActivation
# ---------------------------------------------------------------------
# model.decoder.layers.11.self_attn_layer_norm      LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.11.encoder_attn              BartAttention
# ---------------------------------------------------------------------
# model.decoder.layers.11.encoder_attn.k_proj       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.encoder_attn.v_proj       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.encoder_attn.q_proj       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.encoder_attn.out_proj     Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.encoder_attn_layer_norm   LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layers.11.fc1                       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.fc2                       Linear
# ---------------------------------------------------------------------
# model.decoder.layers.11.final_layer_norm          LayerNorm
# ---------------------------------------------------------------------
# model.decoder.layernorm_embedding                 LayerNorm
# ---------------------------------------------------------------------
# lm_head                                           Linear
# ---------------------------------------------------------------------
